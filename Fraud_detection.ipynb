# %% [markdown]
# <a href="https://colab.research.google.com/github/mariagichomo/Fraud-detection/blob/main/Fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Load Data

# %%
client_df = pd.read_csv("drive/MyDrive/Data/train/client_train.csv")

# %%
client_df.head()
# Out:
#    disrict          client_id  client_catg  region creation_date  target
# 0       60     train_Client_0           11     101    31/12/1994     0.0
# 1       69     train_Client_1           11     107    29/05/2002     0.0
# 2       62    train_Client_10           11     301    13/03/1986     0.0
# 3       69   train_Client_100           11     105    11/07/1996     0.0
# 4       62  train_Client_1000           11     303    14/10/2014     0.0

# %%
invoice_df = pd.read_csv("invoice_train.csv",low_memory=False)

# %%
invoice_df.head()
# Out:
#         client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0  train_Client_0   2014-03-24          11         1335667              0
# 1  train_Client_0   2013-03-29          11         1335667              0
# 2  train_Client_0   2015-03-23          11         1335667              0
# 3  train_Client_0   2015-07-13          11         1335667              0
# 4  train_Client_0   2016-11-17          11         1335667              0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# 0           203                 8                    1                    82
# 1           203                 6                    1                  1200
# 2           203                 8                    1                   123
# 3           207                 8                    1                   102
# 4           207                 9                    1                   572
#
#    consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                     0                     0                     0
# 1                   184                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    old_index  new_index  months_number counter_type
# 0      14302      14384              4         ELEC
# 1      12294      13678              4         ELEC
# 2      14624      14747              4         ELEC
# 3      14747      14849              4         ELEC
# 4      15066      15638             12         ELEC

# %% [markdown]
# ## Data Exploration

# %%
client_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135493 entries, 0 to 135492
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   disrict        135493 non-null  int64
#  1   client_id      135493 non-null  object
#  2   client_catg    135493 non-null  int64
#  3   region         135493 non-null  int64
#  4   creation_date  135493 non-null  object
#  5   target         135493 non-null  float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 6.2+ MB

# %%
invoice_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4476749 entries, 0 to 4476748
# Data columns (total 16 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   client_id             object
#  1   invoice_date          object
#  2   tarif_type            int64
#  3   counter_number        int64
#  4   counter_statue        object
#  5   counter_code          int64
#  6   reading_remarque      int64
#  7   counter_coefficient   int64
#  8   consommation_level_1  int64
#  9   consommation_level_2  int64
#  10  consommation_level_3  int64
#  11  consommation_level_4  int64
#  12  old_index             int64
#  13  new_index             int64
#  14  months_number         int64
#  15  counter_type          object
# dtypes: int64(12), object(4)
# memory usage: 546.5+ MB

# %%
# check missing value
client_df.isnull().sum()
# Out:
# disrict          0
# client_id        0
# client_catg      0
# region           0
# creation_date    0
# target           0
# dtype: int64

# %%
# check missing value
invoice_df.isnull().sum()
# Out:
# client_id               0
# invoice_date            0
# tarif_type              0
# counter_number          0
# counter_statue          0
# counter_code            0
# reading_remarque        0
# counter_coefficient     0
# consommation_level_1    0
# consommation_level_2    0
# consommation_level_3    0
# consommation_level_4    0
# old_index               0
# new_index               0
# months_number           0
# counter_type            0
# dtype: int64

# %%
client_df.duplicated().values.any()
# Out:
# False

# %%
invoice_df.duplicated().values.any()
# Out:
# True

# %%
duplicates =invoice_df.duplicated()

# %%
# Count the number of duplicate rows
num_duplicates = duplicates.sum()

print("Number of duplicate rows:", num_duplicates)
# Out:
# Number of duplicate rows: 11

# %%
duplicates_mask = invoice_df.duplicated(keep=False)

# Use the mask to filter and print the duplicated rows
duplicated_rows = invoice_df[duplicates_mask]
duplicated_rows
# Out:
#                    client_id invoice_date  tarif_type  counter_number  \
# 951890   train_Client_125864   2011-12-12          11          101545
# 951893   train_Client_125864   2011-12-12          11          101545
# 1755789   train_Client_25894   2010-07-13          40         6986740
# 1755798   train_Client_25894   2010-07-13          40         6986740
# 2137995    train_Client_3636   2012-01-18          40          312650
# 2137999    train_Client_3636   2012-01-18          40          312650
# 2163371   train_Client_37069   2010-10-11          11            5284
# 2163374   train_Client_37069   2010-10-11          11            5284
# 2433907   train_Client_44407   2008-02-28          11           66921
# 2433919   train_Client_44407   2008-02-28          11           66921
# 2805727   train_Client_54609   2010-04-06          11          200912
# 2805729   train_Client_54609   2010-04-06          11          200912
# 3260190   train_Client_66981   2006-07-17          11          132701
# 3260191   train_Client_66981   2006-07-17          11          132701
# 3260198   train_Client_66981   2006-07-17          11          132701
# 3394717    train_Client_7066   2014-10-28          40         4463323
# 3394719    train_Client_7066   2014-10-28          40         4463323
# 3462928   train_Client_72519   2013-01-21          11          246464
# 3462929   train_Client_72519   2013-01-21          11          246464
# 3628813   train_Client_77029   2012-12-28          11          540417
# 3628821   train_Client_77029   2012-12-28          11          540417
#
#         counter_statue  counter_code  reading_remarque  counter_coefficient  \
# 951890               5           413                 6                    1
# 951893               5           413                 6                    1
# 1755789              5             5                 6                    1
# 1755798              5             5                 6                    1
# 2137995              5             5                 6                    1
# 2137999              5             5                 6                    1
# 2163371              5           413                 6                    1
# 2163374              5           413                 6                    1
# 2433907              5           203                 6                    1
# 2433919              5           203                 6                    1
# 2805727              5           207                 6                    1
# 2805729              5           207                 6                    1
# 3260190              5           420                 6                    1
# 3260191              5           420                 6                    1
# 3260198              5           420                 6                    1
# 3394717              5             5                 6                    1
# 3394719              5             5                 6                    1
# 3462928              5           203                 6                    1
# 3462929              5           203                 6                    1
# 3628813              5           420                 6                    1
# 3628821              5           420                 6                    1
#
#          consommation_level_1  consommation_level_2  consommation_level_3  \
# 951890                      0                     0                     0
# 951893                      0                     0                     0
# 1755789                     0                     0                     0
# 1755798                     0                     0                     0
# 2137995                     0                     0                     0
# 2137999                     0                     0                     0
# 2163371                     0                     0                     0
# 2163374                     0                     0                     0
# 2433907                     0                     0                     0
# 2433919                     0                     0                     0
# 2805727                     0                     0                     0
# 2805729                     0                     0                     0
# 3260190                     0                     0                     0
# 3260191                     0                     0                     0
# 3260198                     0                     0                     0
# 3394717                     0                     0                     0
# 3394719                     0                     0                     0
# 3462928                     0                     0                     0
# 3462929                     0                     0                     0
# 3628813                     0                     0                     0
# 3628821                     0                     0                     0
#
#          consommation_level_4  old_index  new_index  months_number  \
# 951890                      0      13680      13680              2
# 951893                      0      13680      13680              2
# 1755789                     0          0          0              2
# 1755798                     0          0          0              2
# 2137995                     0        623        623              2
# 2137999                     0        623        623              2
# 2163371                     0      99429      99429              2
# 2163374                     0      99429      99429              2
# 2433907                     0          0          0              2
# 2433919                     0          0          0              2
# 2805727                     0          0          0              2
# 2805729                     0          0          0              2
# 3260190                     0       5946       5946              2
# 3260191                     0       5946       5946              2
# 3260198                     0       5946       5946              2
# 3394717                     0         80         80              2
# 3394719                     0         80         80              2
# 3462928                     0       2954       2954              2
# 3462929                     0       2954       2954              2
# 3628813                     0      26429      26429              2
# 3628821                     0      26429      26429              2
#
#         counter_type
# 951890          ELEC
# 951893          ELEC
# 1755789          GAZ
# 1755798          GAZ
# 2137995          GAZ
# 2137999          GAZ
# 2163371         ELEC
# 2163374         ELEC
# 2433907         ELEC
# 2433919         ELEC
# 2805727         ELEC
# 2805729         ELEC
# 3260190         ELEC
# 3260191         ELEC
# 3260198         ELEC
# 3394717          GAZ
# 3394719          GAZ
# 3462928         ELEC
# 3462929         ELEC
# 3628813         ELEC
# 3628821         ELEC

# %%
#drop duplicates
invoice_df.drop_duplicates(inplace=True)

# %%
# Count the number of duplicate rows
duplicates =invoice_df.duplicated()
num_duplicates = duplicates.sum()

print("Number of duplicate rows:", num_duplicates)
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# ### Test Data

# %%
client_data = {
    'client_id': [1, 2, 3, 4],
    'client_name': ['Client A', 'Client B', 'Client C', 'Client D']
}

# Sample invoice data
invoice_data = {
    'client_id': [1, 2, 1, 3, 4],
    'invoice_number': [101, 102, 103, 104, 105],
    'amount': [500, 300, 700, 200, 900]
}

# Creating DataFrames from the sample data
client = pd.DataFrame(client_data)
invoice = pd.DataFrame(invoice_data)

# %%
client.head()
# Out:
#    client_id client_name
# 0          1    Client A
# 1          2    Client B
# 2          3    Client C
# 3          4    Client D

# %%
invoice
# Out:
#    client_id  invoice_number  amount
# 0          1             101     500
# 1          2             102     300
# 2          1             103     700
# 3          3             104     200
# 4          4             105     900

# %%
# Merging the two datasets based on 'client_id'
merged_df = pd.merge(client, invoice, on='client_id', how='left')

# %%
merged_df
# Out:
#    client_id client_name  invoice_number  amount
# 0          1    Client A             101     500
# 1          1    Client A             103     700
# 2          2    Client B             102     300
# 3          3    Client C             104     200
# 4          4    Client D             105     900

# %%
grouped_df = merged_df.groupby('client_id').agg({
    'client_name': 'first',
    'invoice_number': 'size',
    'amount': 'sum'
}).reset_index()

# %%
grouped_df
# Out:
#    client_id client_name  invoice_number  amount
# 0          1    Client A               2    1200
# 1          2    Client B               1     300
# 2          3    Client C               1     200
# 3          4    Client D               1     900

# %% [markdown]
# ## End of Test Data

# %% [markdown]
# ## Merge our Dataset

# %%
df2 = pd.merge(client_df, invoice_df, on='client_id', how='left')

# %%
df2
# Out:
#          disrict           client_id  client_catg  region creation_date  \
# 0             60      train_Client_0           11     101    31/12/1994
# 1             60      train_Client_0           11     101    31/12/1994
# 2             60      train_Client_0           11     101    31/12/1994
# 3             60      train_Client_0           11     101    31/12/1994
# 4             60      train_Client_0           11     101    31/12/1994
# ...          ...                 ...          ...     ...           ...
# 4476744       60  train_Client_99998           11     101    22/12/1993
# 4476745       60  train_Client_99998           11     101    22/12/1993
# 4476746       60  train_Client_99999           11     101    18/02/1986
# 4476747       60  train_Client_99999           11     101    18/02/1986
# 4476748       60  train_Client_99999           11     101    18/02/1986
#
#          target invoice_date  tarif_type  counter_number counter_statue  ...  \
# 0           0.0   2014-03-24          11         1335667              0  ...
# 1           0.0   2013-03-29          11         1335667              0  ...
# 2           0.0   2015-03-23          11         1335667              0  ...
# 3           0.0   2015-07-13          11         1335667              0  ...
# 4           0.0   2016-11-17          11         1335667              0  ...
# ...         ...          ...         ...             ...            ...  ...
# 4476744     0.0   2005-08-19          10         1253571              0  ...
# 4476745     0.0   2005-12-19          10         1253571              0  ...
# 4476746     0.0   1996-09-25          11          560948              0  ...
# 4476747     0.0   1996-05-28          11          560948              0  ...
# 4476748     0.0   1996-01-25          11          560948              0  ...
#
#          reading_remarque  counter_coefficient  consommation_level_1  \
# 0                       8                    1                    82
# 1                       6                    1                  1200
# 2                       8                    1                   123
# 3                       8                    1                   102
# 4                       9                    1                   572
# ...                   ...                  ...                   ...
# 4476744                 9                    1                   400
# 4476745                 6                    1                   200
# 4476746                 6                    1                   259
# 4476747                 6                    1                   603
# 4476748                 6                    1                   516
#
#          consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                           0                     0                     0
# 1                         184                     0                     0
# 2                           0                     0                     0
# 3                           0                     0                     0
# 4                           0                     0                     0
# ...                       ...                   ...                   ...
# 4476744                   135                     0                     0
# 4476745                     6                     0                     0
# 4476746                     0                     0                     0
# 4476747                     0                     0                     0
# 4476748                     0                     0                     0
#
#          old_index  new_index  months_number  counter_type
# 0            14302      14384              4          ELEC
# 1            12294      13678              4          ELEC
# 2            14624      14747              4          ELEC
# 3            14747      14849              4          ELEC
# 4            15066      15638             12          ELEC
# ...            ...        ...            ...           ...
# 4476744       3197       3732              8          ELEC
# 4476745       3732       3938              4          ELEC
# 4476746      13884      14143              4          ELEC
# 4476747      13281      13884              4          ELEC
# 4476748      12765      13281              4          ELEC
#
# [4476749 rows x 21 columns]

# %%
df2.columns
# Out:
# Index(['disrict', 'client_id', 'client_catg', 'region', 'creation_date',
#        'target', 'invoice_date', 'tarif_type', 'counter_number',
#        'counter_statue', 'counter_code', 'reading_remarque',
#        'counter_coefficient', 'consommation_level_1', 'consommation_level_2',
#        'consommation_level_3', 'consommation_level_4', 'old_index',
#        'new_index', 'months_number', 'counter_type'],
#       dtype='object')

# %%
 df2.groupby('client_id').agg({
    'disrict': 'first',
    'client_catg':'first',
    'region':'first',
    'creation_date':'first',
    'invoice_date':'size',
     'consommation_level_1':'sum',
     'target':'first'
}).reset_index()
# Out:
#                  client_id  disrict  client_catg  region creation_date  \
# 0           train_Client_0       60           11     101    31/12/1994
# 1           train_Client_1       69           11     107    29/05/2002
# 2          train_Client_10       62           11     301    13/03/1986
# 3         train_Client_100       69           11     105    11/07/1996
# 4        train_Client_1000       62           11     303    14/10/2014
# ...                    ...      ...          ...     ...           ...
# 135488  train_Client_99995       62           11     304    26/07/2004
# 135489  train_Client_99996       63           11     311    25/10/2012
# 135490  train_Client_99997       63           11     311    22/11/2011
# 135491  train_Client_99998       60           11     101    22/12/1993
# 135492  train_Client_99999       60           11     101    18/02/1986
#
#         invoice_date  consommation_level_1  target
# 0                 35                 12334     0.0
# 1                 37                 20629     0.0
# 2                 18                 14375     0.0
# 3                 20                    24     0.0
# 4                 14                  9292     0.0
# ...              ...                   ...     ...
# 135488            71                   139     0.0
# 135489            41                  7620     0.0
# 135490            36                  9831     0.0
# 135491             2                   600     0.0
# 135492             3                  1378     0.0
#
# [135493 rows x 8 columns]

# %%
df2['creation_date'].max()
# Out:
# '31/12/2018'

# %%
df2['Account Age']= 2019- df2['creation_date']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\roperator.py:15, in rsub(left, right)
#      14 def rsub(left, right):
# ---> 15     return right - left
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
# ----> 1 df2['Account Age']= 2019- df2['creation_date']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:198, in OpsMixin.__rsub__(self, other)
#     196 @unpack_zerodim_and_defer("__rsub__")
#     197 def __rsub__(self, other):
# --> 198     return self._arith_method(other, roperator.rsub)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:5815, in Series._arith_method(self, other, op)
#    5813 def _arith_method(self, other, op):
#    5814     self, other = self._align_for_op(other)
# -> 5815     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\base.py:1381, in IndexOpsMixin._arith_method(self, other, op)
#    1378     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1380 with np.errstate(all="ignore"):
# -> 1381     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1383 return self._construct_result(result, name=res_name)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:285, in arithmetic_op(left, right, op)
#     281     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     283     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 285     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     287 return res_values
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:229, in _na_arithmetic_op(left, right, op, is_cmp)
#     221 except TypeError:
#     222     if not is_cmp and (
#     223         left.dtype == object or getattr(right, "dtype", None) == object
#     224     ):
#    (...)
#     227         # Don't do this for comparisons, as that will handle complex numbers
#     228         #  incorrectly, see GH#32047
# --> 229         result = _masked_arith_op(left, right, op)
#     230     else:
#     231         raise
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:184, in _masked_arith_op(x, y, op)
#     181         mask = np.where(y == 1, False, mask)
#     183     if mask.any():
# --> 184         result[mask] = op(xrav[mask], y)
#     186 np.putmask(result, ~mask, np.nan)
#     187 result = result.reshape(x.shape)  # 2D compat
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\roperator.py:15, in rsub(left, right)
#      14 def rsub(left, right):
# ---> 15     return right - left
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'
